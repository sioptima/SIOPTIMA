# %% [markdown]
# # 1.) AUTHENTICATION API

# %% [markdown]
# // Logout
# POST /api/auth/logout
#
# Response:
# {
#   "success": true,
#   "message": "Logout successful"
# }

# %% [markdown]
# # 2.) AUTHENTICATION API

# %% [markdown]
# ### a.) Get Dashboard Summary

# %% [markdown]
# GET /api/admin/dashboard/summary
#
# Response:
# {
#   "success": true,
#   "data": {
#     "totalSites": 5,
#     "totalSitesTrend": 4.2,
#     "activeOperators": 1,
#     "activeOperatorsTrend": 2.1,
#     "dailyReports": 5,
#     "dailyReportsTrend": 8.5,
#     "complianceRate": 40,
#     "complianceRateTrend": 1.2,
#     "activeSites": 3,
#     "maintenanceSites": 1,
#     "inactiveSites": 1,
#     "approvedReports": 2,
#     "pendingReports": 2,
#     "rejectedReports": 1
#   }
# }

# %% [markdown]
# ### b.) Get Water Quality Trends

# %% [markdown]
# GET /api/admin/dashboard/water-quality
#
# Response:
# {
#   "success": true,
#   "data": {
#     "period": "week",
#     "data": [
#       { "day": "Mon", "ec": 670, "tds": 440, "pH": 7.0 },
#       { "day": "Tue", "ec": 720, "tds": 480, "pH": 6.8 },
#       { "day": "Wed", "ec": 580, "tds": 390, "pH": 7.2 },
#       { "day": "Thu", "ec": 810, "tds": 520, "pH": 6.9 },
#       { "day": "Fri", "ec": 630, "tds": 410, "pH": 7.1 },
#       { "day": "Sat", "ec": 590, "tds": 380, "pH": 7.3 },
#       { "day": "Sun", "ec": 690, "tds": 450, "pH": 7.0 }
#     ]
#   }
# }

# %% [markdown]
# ### c.) Get Report Status Distribution

# %% [markdown]
# GET /api/admin/dashboard/report-status
#
# Response:
# {
#   "success": true,
#   "data": [
#     {
#       "status": "approved",
#       "value": 40,
#       "count": 2,
#       "color": "#10B981"
#     },
#     {
#       "status": "pending",
#       "value": 40,
#       "count": 2,
#       "color": "#F59E0B"
#     },
#     {
#       "status": "rejected",
#       "value": 20,
#       "count": 1,
#       "color": "#EF4444"
#     }
#   ]
# }

# %% [markdown]
# ### d.) Get Site Performance

# %% [markdown]
# GET /api/admin/dashboard/site-performance
#
# Response:
# {
#   "success": true,
#   "data": [
#     {
#       "siteId": 1,
#       "siteName": "Jakarta Utara - Site A",
#       "city": "Jakarta Utara",
#       "compliance": 50,
#       "reports": 2,
#       "operators": 3
#     },
#     {
#       "siteId": 2,
#       "siteName": "Bandung - Site B",
#       "city": "Bandung",
#       "compliance": 50,
#       "reports": 2,
#       "operators": 2
#     },
#     {
#       "siteId": 3,
#       "siteName": "Surabaya - Site C",
#       "city": "Surabaya",
#       "compliance": 0,
#       "reports": 1,
#       "operators": 4
#     }
#   ]
# }

# %% [markdown]
# ### e.) Get Recent Reports

# %% [markdown]
# GET /api/admin/dashboard/recent-reports?limit=5
#
# Response:
# {
#   "success": true,
#   "data": [
#     {
#       "id": 1,
#       "date": "2024-01-27",
#       "time": "08:30",
#       "site": "Jakarta Utara - Site A",
#       "operator": "Budi Santoso",
#       "pH": 7.2,
#       "flowRate": "450 L/h",
#       "status": "pending"
#     },
#     {
#       "id": 2,
#       "date": "2024-01-27",
#       "time": "08:15",
#       "site": "Bandung - Site B",
#       "operator": "Siti Nurhaliza",
#       "pH": 6.8,
#       "flowRate": "380 L/h",
#       "status": "approved"
#     }
#   ]
# }

# %% [markdown]
# ### f.) Get System Alerts

# %% [markdown]
# GET /api/admin/dashboard/system-alerts
#
# Response:
# {
#   "success": true,
#   "data": [
#     {
#       "id": 1,
#       "severity": "high",
#       "title": "pH level above threshold at Site Jakarta B",
#       "timeAgo": "1 hour ago"
#     },
#     {
#       "id": 2,
#       "severity": "medium",
#       "title": "2 reports pending validation",
#       "timeAgo": "2 hours ago"
#     },
#     {
#       "id": 3,
#       "severity": "low",
#       "title": "All sites reported successfully today",
#       "timeAgo": "5 hours ago"
#     }
#   ]
# }

# %% [markdown]
# ### g.) Acknowledge Alert

# %% [markdown]
# POST /api/admin/dashboard/alerts/:alertId/acknowledge
#
# Response:
# {
#   "success": true,
#   "message": "Alert acknowledged successfully"
# }

# %% [markdown]
# # 3.) MENU SITES MANAGEMENT API

# %% [markdown]
# ### a.) Get All Sites

# %% [markdown]
# GET /api/sites
#
# Response:
# {
#   "success": true,
#   "data": [
#     {
#       "id": 1,
#       "name": "Jakarta Utara - Site A",
#       "city": "Jakarta Utara",
#       "address": "Jl. Industri No. 123, Jakarta Utara",
#       "province": "DKI Jakarta",
#       "operators": 3,
#       "status": "active",
#       "lastReport": "2 hours ago"
#     },
#     {
#       "id": 2,
#       "name": "Bandung - Site B",
#       "city": "Bandung",
#       "address": "Jl. Soekarno Hatta No. 456, Bandung",
#       "province": "Jawa Barat",
#       "operators": 2,
#       "status": "active",
#       "lastReport": "3 hours ago"
#     }
#   ],
#
#   "pagination": {
#     "total": 5,
#     "page": 1,
#     "limit": 10,
#     "totalPages": 1
#   }
# }

# %% [markdown]
# ### b.) Get Site by ID

# %% [markdown]
# GET /api/sites/1
#
# Response:
# {
#   "success": true,
#   "data": {
#     "id": 1,
#     "name": "Jakarta Utara - Site A",
#     "city": "Jakarta Utara",
#     "address": "Jl. Industri No. 123, Jakarta Utara",
#     "province": "DKI Jakarta",
#     "operators": 3,
#     "status": "active",
#     "lastReport": "2 hours ago",
#     "createdAt": "2024-01-01T00:00:00Z",
#     "updatedAt": "2024-01-27T08:30:00Z"
#   }
# }

# %% [markdown]
# ### c.) Create New Site

# %% [markdown]
# POST /api/sites
# Body: {
#   "name": "Jakarta Pusat - Site F",
#   "city": "Jakarta Pusat",
#   "address": "Jl. Thamrin No. 100, Jakarta Pusat",
#   "province": "DKI Jakarta",
#   "status": "active"
# }
#
# Response:
# {
#   "success": true,
#   "data": {
#     "id": 6,
#     "name": "Jakarta Pusat - Site F",
#     "city": "Jakarta Pusat",
#     "address": "Jl. Thamrin No. 100, Jakarta Pusat",
#     "province": "DKI Jakarta",
#     "operators": 0,
#     "status": "active",
#     "lastReport": "Just now"
#   },
#   "message": "Site created successfully"
# }

# %% [markdown]
# ### d.) Update Site

# %% [markdown]
# PUT /api/sites/1
# Body: {
#   "name": "Jakarta Utara - Site A Updated",
#   "city": "Jakarta Utara",
#   "address": "Jl. Industri No. 123A, Jakarta Utara",
#   "province": "DKI Jakarta",
#   "status": "active"
# }
#
# Response:
# {
#   "success": true,
#   "data": {
#     "id": 1,
#     "name": "Jakarta Utara - Site A Updated",
#     "city": "Jakarta Utara",
#     "address": "Jl. Industri No. 123A, Jakarta Utara",
#     "province": "DKI Jakarta",
#     "operators": 3,
#     "status": "active",
#     "lastReport": "2 hours ago"
#   },
#   "message": "Site updated successfully"
# }

# %% [markdown]
# ### e.) Delete Site

# %% [markdown]
# DELETE /api/sites/1
#
# Response:
# {
#   "success": true,
#   "message": "Site deleted successfully"
# }

# %% [markdown]
# # 4.) MENU USERS MANAGEMENT API

# %% [markdown]
# ### a.) Get All Users

# %% [markdown]
# GET /api/users
#
# Response:
# {
#   "success": true,
#   "data": [
#     {
#       "id": 1,
#       "name": "Budi Santoso",
#       "email": "budi.santoso@email.com",
#       "role": "operator",
#       "site": "Jakarta Utara - Site A",
#       "status": "active",
#       "lastActive": "2 hours ago",
#       "initial": "B"
#     },
#     {
#       "id": 2,
#       "name": "Katira Sala",
#       "email": "katira.sala@email.com",
#       "role": "hrd",
#       "site": "Central Office",
#       "status": "active",
#       "lastActive": "1 day ago",
#       "initial": "K"
#     }
#   ],
#   "pagination": {
#     "total": 4,
#     "page": 1,
#     "limit": 10,
#     "totalPages": 1
#   }
# }

# %% [markdown]
# ### b.) Get User by ID

# %% [markdown]
# GET /api/users/1
#
# Response:
# {
#   "success": true,
#   "data": {
#     "id": 1,
#     "name": "Budi Santoso",
#     "email": "budi.santoso@email.com",
#     "role": "operator",
#     "site": "Jakarta Utara - Site A",
#     "status": "active",
#     "lastActive": "2 hours ago",
#     "initial": "B",
#     "createdAt": "2024-01-01T00:00:00Z",
#     "updatedAt": "2024-01-27T08:30:00Z"
#   }
# }

# %% [markdown]
# ### c.) Create New User

# %% [markdown]
# POST /api/users
# Body: {
#   "name": "John Doe",
#   "email": "john.doe@email.com",
#   "role": "operator",
#   "site": "Jakarta Utara - Site A",
#   "status": "active"
# }
#
# Response:
# {
#   "success": true,
#   "data": {
#     "id": 5,
#     "name": "John Doe",
#     "email": "john.doe@email.com",
#     "role": "operator",
#     "site": "Jakarta Utara - Site A",
#     "status": "active",
#     "lastActive": "Just now",
#     "initial": "J"
#   },
#   "message": "User created successfully"
# }

# %% [markdown]
# ### d.) Update User

# %% [markdown]
# PUT /api/users/1
# Body: {
#   "name": "Budi Santoso Updated",
#   "email": "budi.updated@email.com",
#   "role": "operator",
#   "site": "Jakarta Utara - Site A",
#   "status": "active"
# }
#
# Response:
# {
#   "success": true,
#   "data": {
#     "id": 1,
#     "name": "Budi Santoso Updated",
#     "email": "budi.updated@email.com",
#     "role": "operator",
#     "site": "Jakarta Utara - Site A",
#     "status": "active",
#     "lastActive": "2 hours ago",
#     "initial": "B"
#   },
#   "message": "User updated successfully"
# }

# %% [markdown]
# ### e.) Delete User

# %% [markdown]
# DELETE /api/users/1
#
# Response:
# {
#   "success": true,
#   "message": "User deleted successfully"
# }

# %% [markdown]
# # 5.) MENU REPORTS MANAGEMENT API

# %% [markdown]
# ### a.) Get All Reports

# %% [markdown]
# GET /api/reports
#
# Response:
# {
#   "success": true,
#   "data": [
#     {
#       "id": 1,
#       "date": "2024-01-27",
#       "time": "08:30",
#       "site": "Jakarta Utara - Site A",
#       "operator": "Budi Santoso",
#       "pH": 7.2,
#       "flowRate": "450 L/h",
#       "status": "pending"
#     },
#     {
#       "id": 2,
#       "date": "2024-01-27",
#       "time": "08:15",
#       "site": "Bandung - Site B",
#       "operator": "Siti Nurhaliza",
#       "pH": 6.8,
#       "flowRate": "380 L/h",
#       "status": "approved"
#     }
#   ],
#   "pagination": {
#     "total": 5,
#     "page": 1,
#     "limit": 10,
#     "totalPages": 1
#   }
# }

# %% [markdown]
# ### b.) Get Report by ID

# %% [markdown]
# GET /api/reports/1
#
# Response:
# {
#   "success": true,
#   "data": {
#     "id": 1,
#     "date": "2024-01-27",
#     "time": "08:30",
#     "site": "Jakarta Utara - Site A",
#     "operator": "Budi Santoso",
#     "pH": 7.2,
#     "flowRate": "450 L/h",
#     "status": "pending",
#     "details": {
#       "temperature": "28°C",
#       "tds": "450 ppm",
#       "turbidity": "2.5 NTU",
#       "chlorine": "1.2 mg/L",
#       "notes": "Semua parameter dalam batas normal. Operasi berjalan lancar.",
#       "images": ["sample1.jpg", "sample2.jpg"]
#     },
#     "createdAt": "2024-01-27T08:30:00Z"
#   }
# }

# %% [markdown]
# ### c.) Approve Report

# %% [markdown]
# PUT /api/reports/1/approve
#
# Response:
# {
#   "success": true,
#   "data": {
#     "id": 1,
#     "status": "approved"
#   },
#   "message": "Report approved successfully"
# }

# %% [markdown]
# ### d.) Reject Report

# %% [markdown]
# PUT /api/reports/1/reject
#
# Response:
# {
#   "success": true,
#   "data": {
#     "id": 1,
#     "status": "rejected"
#   },
#   "message": "Report rejected successfully"
# }

# %% [markdown]
# ### e.) Export Reports

# %% [markdown]
# GET /api/reports/export?format=pdf&dateRange=today&status=all&search=&site=all
#
# Response (File Download):
# - PDF file atau CSV file dengan data laporan
# - Atau response JSON dengan download link:
#
# {
#   "success": true,
#   "data": {
#     "downloadUrl": "/api/reports/export/file/export-12345.pdf",
#     "filename": "laporan-ipal-2024-01-27.pdf",
#     "expiresAt": "2024-01-27T23:59:59Z"
#   },
#   "message": "Export generated successfully"
# }

# %% [markdown]
# ### f.) Error Response Format (Untuk Semua Endpoint)

# %% [markdown]
# {
#   "success": false,
#   "error": "Error message description",
#   "code": "ERROR_CODE",
#   "details": {
#     // Optional: validation errors or additional details
#   }
# }
